# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_eda=pd.read_csv("./Dataset/insurance.csv")

# %% [markdown]
# # EDA
#
#
# #### We will analyze the below stuff
#
# * Missing values
# * Listing all the numerical variables
# * Distribution of the numerical variables
# * Categorical Variables
# * Outliers
# * Relationship between independent and dependent features
# * Correlation

# %% [markdown]
# ### Missing Values

# %%
df_eda.rename(columns={'expenses':'premium'}, inplace=True)

# %%
df_eda.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# premium     0
# dtype: int64

# %% [markdown]
# ### Obs. 1
#
# #### Well, there are no missing values. Probably each column is relevant and signifact

# %% [markdown]
# ### Creating independent columns and dependent variable list

# %%
df_indi=df_eda.iloc[:,:-1]

# %%
df_dep=df_eda.iloc[:,-1]

# %%
for i in range(len(df_indi.columns)):
    plt.scatter(df_indi.iloc[:,i], df_dep)
    plt.xlabel(df_indi.columns[i])
    plt.ylabel('Premium')
    plt.show()

# %% [markdown]
# ### Obs 2.

# %% [markdown]
# ##### There is no direct linear relationship with premium for region and sex

# %% [markdown]
# ### Isolating Numerical features

# %%
numerical_col=[num_feat for num_feat in df_indi.columns if df_indi[num_feat].dtypes!='O']

# %%
numerical_col
# Out:
# ['age', 'bmi', 'children']

# %%
for i in numerical_col:
    df_indi[[i]].boxplot(column=i)
    plt.show()

# %%
df_eda[df_eda['premium']==df_eda['premium'].min()]
# Out:
#      age     sex   bmi  children smoker     region   premium
# 543   54  female  47.4         0    yes  southeast  63770.43

# %%
df_eda[['children', 'premium']][df_eda['children']>3]
# Out:
#       children   premium
# 32           5   4687.80
# 61           4   4504.66
# 71           5   6799.46
# 83           4  11033.66
# 165          4  10407.09
# 166          5   4830.63
# 211          4   8162.72
# 258          4  11520.10
# 321          4  24671.66
# 344          4  10977.21
# 390          4  10736.87
# 413          5   5080.10
# 425          5   9788.87
# 438          5  12592.53
# 450          4   7512.27
# 494          4  17942.11
# 568          5  11552.90
# 621          4  40182.25
# 639          4  12949.16
# 640          5   6666.24
# 659          4  14394.40
# 754          4  17128.43
# 877          5   6653.79
# 884          4   4877.98
# 891          4   7243.81
# 932          5  10096.97
# 937          5   8965.80
# 969          5   8596.83
# 984          5   4915.06
# 1012         4  36580.28
# 1064         4   5708.87
# 1085         5  19023.26
# 1094         4  11299.34
# 1095         4   4561.19
# 1116         5   9222.40
# 1130         5   8582.30
# ...
